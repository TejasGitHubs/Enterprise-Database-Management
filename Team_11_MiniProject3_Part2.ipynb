# %%
from pymongo import MongoClient
import pandas as pd

# !pip install dnspython
import dns
# Out:
# ...
#      |████████████████████████████████| 269 kB 25.4 MB/s
# ...

# %%
#Creating URL for connecting to Database on MongoDB
url = "mongodb://mathewjose47:BADM554@badm554-shard-00-00.44oda.mongodb.net:27017,badm554-shard-00-01.44oda.mongodb.net:27017,badm554-shard-00-02.44oda.mongodb.net:27017/myFirstDatabase?ssl=true&replicaSet=atlas-e16bus-shard-0&authSource=admin&retryWrites=true&w=majority"

#Initializing the client for MongoDB using the credentials
client = MongoClient(url)

# %%
#Connecting to Yelp Database
db = client.get_database("Yelp")

# %%
#Checking the record count for both the tables
reviewrecords = db.Review
reviewrecords.count_documents({})
# Out:
# 597

# %%
businessrecords = db.Business
businessrecords.count_documents({})
# Out:
# 18939

# %%
#Converting Document to Panda DF
business = pd.DataFrame(list(db.Business.find()))
business.head()
# Out:
#                         _id    0                       1  \
# 0  619b16e38a8d577abd2fbfd6  225  So4sUPedGUcyEMRAmDRgDw
# 1  619b16e38a8d577abd2fbfe4  299  LHPzReyrFStB08KwMcyP2w
# 2  619b16e38a8d577abd2fbfdf  310  Xz6aqENKlT4FU-ZBvrf_ow
# 3  619b16e38a8d577abd2fbfd4   51  w4qVflIAbdklzG3mnKmQsg
# 4  619b16e38a8d577abd2fbfef  382  zjWGMm1SGJWeSaDpVVDU4g
#
#                            2                          3        4   5      6  \
# 0              Sabatino & Co             130 Newbury St   Boston  MA  02116
# 1  Boat Cruise Summer Series           200 Seaport Blvd   Boston  MA  02210
# 2                Bugambilias            747 W Lancaster  Orlando  FL  32809
# 3      Magical Pizza Express  3262 Vineland Rd, Ste 106  Orlando  FL  32811
# 4    Modell's Sporting Goods            480 Boylston St   Boston  MA  02116
#
#            7          8    9  10  11  \
# 0  42.351049 -71.076655  4.5   8   0
# 1  42.351367 -71.040491  3.0   5   1
# 2  28.464982 -81.390952  4.5  43   1
# ...

# %%
#Converting Business Document to Pandas DF
review = pd.DataFrame(list(db.Review.find()))
review.head()
# Out:
#                         _id               review_id                 user_id  \
# 0  619b16fa0e1d835e510a8be2  Kb_1Krtb5VgGdfivx7cmww  RXpxsLvw3v7LPhVAPNRvRw
# 1  619b16fa0e1d835e510a8b3a  KbXU4-SJqfxrW5-jcB73HQ  WXSCghMqWGY_tmfRrvlANQ
# 2  619b16fa0e1d835e510a8c0e  iQ9m2jD9_ebtAbnyQxgmcg  57tf_RmT5o3BiFj2gpV-Jg
# 3  619b16fa0e1d835e510a8b3d  pPbjcUiFIShdQq1mIOXc9Q  nkN_do3fJ9xekchVC-v68A
# 4  619b16fa0e1d835e510a8b2c  WxrK52MRJy6Cxk_vOJeD1Q  9d22a-5XXvsZ55p04gI5jA
#
#               business_id  stars  useful  funny  cool  \
# 0  paHbKmPjwirnIP7esoTPCQ      4       0      0     0
# 1  RDuPefU1ZBP6OyolshXvGw      5       1      0     0
# 2  YCasSG_q_DdhWR6H1nhJ9A      4       0      0     0
# 3  v5M1mNsDCQF0vLsRCMD0kQ      2       0      0     0
# 4  _gOz7-aHMyGUHOtjDrEv2w      2       4      2     0
#
#                                                 text           date
# 0  Good food and pleasant service. Self seating c...  1446775413000
# ...

# %%
#Outer joining the two DF using 12 (Business ID ) from Business, and business_id from review dfs
business_review = pd.merge(business, review, how = 'outer', left_on=['1'], right_on=['business_id'])

business_review.head()
# Out:
#                       _id_x    0                       1  \
# 0  619b16e38a8d577abd2fbfd6  225  So4sUPedGUcyEMRAmDRgDw
# 1  619b16e38a8d577abd2fbfe4  299  LHPzReyrFStB08KwMcyP2w
# 2  619b16e38a8d577abd2fbfdf  310  Xz6aqENKlT4FU-ZBvrf_ow
# 3  619b16e38a8d577abd2fbfd4   51  w4qVflIAbdklzG3mnKmQsg
# 4  619b16e38a8d577abd2fbfef  382  zjWGMm1SGJWeSaDpVVDU4g
#
#                            2                          3        4   5      6  \
# 0              Sabatino & Co             130 Newbury St   Boston  MA  02116
# 1  Boat Cruise Summer Series           200 Seaport Blvd   Boston  MA  02210
# 2                Bugambilias            747 W Lancaster  Orlando  FL  32809
# 3      Magical Pizza Express  3262 Vineland Rd, Ste 106  Orlando  FL  32811
# 4    Modell's Sporting Goods            480 Boylston St   Boston  MA  02116
#
#            7          8  ...  _id_y  review_id  user_id business_id stars  \
# 0  42.351049 -71.076655  ...    NaN        NaN      NaN         NaN   NaN
# ...

# %%
#Filterting the rows which only contains "Restaurant" in category (12)
restaurant_review = business_review[business_review['12'].str.contains('Restaurant', na= False)]

restaurant_review.head(50)
# Out:
#                         _id_x     0                       1  \
# 2    619b16e38a8d577abd2fbfdf   310  Xz6aqENKlT4FU-ZBvrf_ow
# 3    619b16e38a8d577abd2fbfd4    51  w4qVflIAbdklzG3mnKmQsg
# 7    619b16e38a8d577abd2fbfdb   220  y030N-DD6G7lfWHO4A6ezw
# 24   619b16e38a8d577abd2fc0ca  2039  YMwzbodNWxRxhY1Wz5gE1A
# 25   619b16e38a8d577abd2fbfd5    63  qbZJh9lR0gh4Wca96NQv9g
# 26   619b16e38a8d577abd2fc05c  1283  3SUhbtzb49gJX9jvitGSFQ
# 27   619b16e38a8d577abd2fc065  1206  ZjizmUFYq7NP8N-FAbtzFw
# 37   619b16e38a8d577abd2fc084  1508  oYpQs22iUr68hSiTh7pMRA
# 38   619b16e38a8d577abd2fc084  1508  oYpQs22iUr68hSiTh7pMRA
# 40   619b16e38a8d577abd2fc0d8  2201  DJjeZa1e6t3vrUr-biIWvQ
# 43   619b16e38a8d577abd2fc0f9  2429  OTqUbo5LfSJXULw742jPJw
# 44   619b16e38a8d577abd2fbff1   436  xqxRL30UDtEP3v1E_x-SlA
# 45   619b16e38a8d577abd2fc092  1598  4HiYQ84s7Mqy7iY8vp9_xA
# 47   619b16e38a8d577abd2fc0b5  1845  n15kZTmPh7DmSdAYk4Gf7Q
# 49   619b16e38a8d577abd2fc054  1062  0c8NZgbg1Q0vwXMPZTUlvA
# ...
